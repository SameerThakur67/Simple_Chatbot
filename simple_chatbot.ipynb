# %%
# !pip install langgraph typing langchain_groq langchain_core

# %%
from httpx import Response
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_groq import ChatGroq
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver
import os

os.environ["GROQ_API_KEY"] = "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"  # or set it outside in your OS

llm = ChatGroq(model="llama-3.1-8b-instant")
class ChatState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]

def chat_node(state: ChatState):
    messages = state["messages"]
    response = llm.invoke(messages)
    return {"messages": [response]}

graph = StateGraph(ChatState)
checkpoint= MemorySaver()
graph.add_node("chat_node", chat_node)
graph.add_edge(START, "chat_node")
graph.add_edge("chat_node", END)

chatbot = graph.compile(checkpointer=checkpoint)

thread_id=1
while True:

  a = input("enter the text:")

  if a.strip().lower() in ["exit","bye","quit"]:
    break
  config ={"configurable":{"thread_id":thread_id}}
  Response = chatbot.invoke({"messages":[HumanMessage(content=a)]},config=config)["messages"][-1].content
  print(Response)
# Out:
# enter the text:hello
# Hello. How can I assist you today?
# enter the text:my name is sameer
# Nice to meet you, Sameer. Is there something I can help you with or would you like to chat?
# enter the text:what is my name
# Your name is Sameer.
# enter the text:bye bro
# Later Sameer, have a great day!
# enter the text:plzz exit
# It was nice chatting with you, Sameer. Goodbye.
# enter the text:exit

# %%
import os
from groq import Groq

client = Groq(api_key="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")
models = client.models.list()
for m in models.data:
    print(m.id)
# Out:
# moonshotai/kimi-k2-instruct
# playai-tts-arabic
# openai/gpt-oss-safeguard-20b
# groq/compound-mini
# moonshotai/kimi-k2-instruct-0905
# meta-llama/llama-4-scout-17b-16e-instruct
# meta-llama/llama-4-maverick-17b-128e-instruct
# meta-llama/llama-guard-4-12b
# openai/gpt-oss-20b
# llama-3.3-70b-versatile
# groq/compound
# openai/gpt-oss-120b
# qwen/qwen3-32b
# playai-tts
# meta-llama/llama-prompt-guard-2-86m
# meta-llama/llama-prompt-guard-2-22m
# whisper-large-v3
# allam-2-7b
# whisper-large-v3-turbo
# llama-3.1-8b-instant
